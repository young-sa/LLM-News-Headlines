# %%
import os
import requests
import pandas as pd
from dotenv import load_dotenv
import openai
import time
from openai import OpenAI

# %%
models = client.models.list()
for model in models.data:
    print(model.id)
# Out:
# gpt-4-0613
# gpt-4
# gpt-3.5-turbo
# gpt-4o-audio-preview-2025-06-03
# gpt-4.1-nano-2025-04-14
# gpt-4.1-nano
# gpt-image-1
# gpt-4o-realtime-preview-2025-06-03
# davinci-002
# babbage-002
# gpt-3.5-turbo-instruct
# gpt-3.5-turbo-instruct-0914
# dall-e-3
# dall-e-2
# gpt-4-1106-preview
# gpt-3.5-turbo-1106
# tts-1-hd
# tts-1-1106
# tts-1-hd-1106
# text-embedding-3-small
# text-embedding-3-large
# gpt-4-0125-preview
# gpt-4-turbo-preview
# gpt-3.5-turbo-0125
# gpt-4-turbo
# gpt-4-turbo-2024-04-09
# gpt-4o
# gpt-4o-2024-05-13
# gpt-4o-mini-2024-07-18
# gpt-4o-mini
# gpt-4o-2024-08-06
# chatgpt-4o-latest
# o1-mini-2024-09-12
# o1-mini
# gpt-4o-realtime-preview-2024-10-01
# gpt-4o-audio-preview-2024-10-01
# gpt-4o-audio-preview
# gpt-4o-realtime-preview
# omni-moderation-latest
# omni-moderation-2024-09-26
# gpt-4o-realtime-preview-2024-12-17
# gpt-4o-audio-preview-2024-12-17
# gpt-4o-mini-realtime-preview-2024-12-17
# gpt-4o-mini-audio-preview-2024-12-17
# o1-2024-12-17
# o1
# gpt-4o-mini-realtime-preview
# gpt-4o-mini-audio-preview
# o3-mini
# o3-mini-2025-01-31
# gpt-4o-2024-11-20
# gpt-4o-search-preview-2025-03-11
# gpt-4o-search-preview
# gpt-4o-mini-search-preview-2025-03-11
# gpt-4o-mini-search-preview
# gpt-4o-transcribe
# gpt-4o-mini-transcribe
# o1-pro-2025-03-19
# o1-pro
# gpt-4o-mini-tts
# gpt-4.1-2025-04-14
# gpt-4.1
# gpt-4.1-mini-2025-04-14
# gpt-4.1-mini
# gpt-3.5-turbo-16k
# tts-1
# whisper-1
# text-embedding-ada-002

# %%
#news api limits it to 100 for the free plan
load_dotenv()

NEWS_API_KEY = os.getenv("NEWS_API_KEY")

def fetch_headlines(query="AI", page_size=100):
    url = (
        f"https://newsapi.org/v2/everything?"
        f"q={query}&language=en&pageSize={page_size}&apiKey={NEWS_API_KEY}"
    )
    response = requests.get(url)
    data = response.json()

    headlines = [
        {"title": article["title"], "source": article["source"]["name"]}
        for article in data.get("articles", [])
    ]
    return pd.DataFrame(headlines)

# headlines
df = fetch_headlines("AI", page_size=100)
print(f"Total headlines retrieved: {len(df)}")
print(df.head())
# Out:
# Total headlines retrieved: 100
#                                                title     source
# 0                Join Us for WIRED’s AI Power Summit      Wired
# 1                        Where Are All the AI Drugs?      Wired
# 2         Confessions of a Recovering AI Porn Addict      Wired
# 3  Android’s Circle to Search feature gets AI and...  The Verge
# 4  Amazon buys Bee AI wearable that listens to ev...  The Verge

# %%
openai.api_key = os.getenv("OPENAI_API_KEY")

client = OpenAI()  # uses your OPENAI_API_KEY from .env

def extract_features_from_headline(headline):
    prompt = f"""
Analyze the following news headline and extract the following features:

Headline: "{headline}"

1. Sentiment (Positive, Negative, Neutral)
2. Main Topic (e.g., Politics, Finance, Technology, etc.)
3. Named Entities (People, Companies, Organizations)
4. Tone (e.g., Informative, Alarmist, Speculative, Promotional, Neutral)
5. Region/Location (e.g., US, Europe, China, Global, Unknown)
6. Intent of the headline (e.g., Report news, Persuade, Warn, Promote)
7. Time relevance (Past, Present, Future)
8. Emotion(s) evoked (e.g., Fear, Hope, Anger, Curiosity)
9. Is this headline clickbait? (Yes/No)

Respond in this format:
Sentiment: ...
Topic: ...
Entities: ...
Tone: ...
Region: ...
Intent: ...
Time: ...
Emotions: ...
Clickbait: ...
"""

    try:
        response = client.chat.completions.create(
            model="gpt-4o",  # ✅ Use gpt-4o here
            messages=[{"role": "user", "content": prompt}],
            temperature=0.3,
        )
        return response.choices[0].message.content
    except Exception as e:
        print(f"Error: {e}")
        return None

# %%
def process_headlines(df):
    results = []

    for i, row in df.iterrows():
        print(f"Processing {i+1}/{len(df)}: {row['title']}")
        result = extract_features_from_headline(row['title'])
        time.sleep(1.5)

        if result:
            extracted = {
                "headline": row["title"],
                "source": row["source"],
                "sentiment": "N/A",
                "topic": "N/A",
                "entities": "N/A",
                "tone": "N/A",
                "region": "N/A",
                "intent": "N/A",
                "time": "N/A",
                "emotions": "N/A",
                "clickbait": "N/A"
            }

            for line in result.splitlines():
                for key in extracted.keys():
                    if line.lower().startswith(f"{key}:".lower()):
                        extracted[key] = line.split(":", 1)[1].strip()

            results.append(extracted)

    return pd.DataFrame(results)

# %%
labeled_df = process_headlines(df)
labeled_df.to_csv("labeled_headlines.csv", index=False)
print("Saved labeled_headlines.csv")
# Out:
# Processing 1/100: Join Us for WIRED’s AI Power Summit
# Processing 2/100: Where Are All the AI Drugs?
# Processing 3/100: Confessions of a Recovering AI Porn Addict
# Processing 4/100: Android’s Circle to Search feature gets AI and gaming upgrades
# Processing 5/100: Amazon buys Bee AI wearable that listens to everything you say
# Processing 6/100: Meta snubs the EU’s voluntary AI guidelines
# Processing 7/100: Google AI Mode will generate fake clothes to help you buy real ones
# Processing 8/100: Breaking down Trump’s big gift to the AI industry
# Processing 9/100: Perplexity just launched an AI web browser
# Processing 10/100: The creepy AI era is here
# Processing 11/100: People Are Using AI Chatbots to Guide Their Psychedelic Trips
# Processing 12/100: Bryan Johnson Is Going to Die
# Processing 13/100: Elon Musk teases AI anime boyfriend based on Edward Cullen
# Processing 14/100: Proton is launching a privacy-focused AI chatbot
# Processing 15/100: Figma’s AI app building tool is now available for everyone
# Processing 16/100: Yelp is creating its own AI videos about restaurants
# Processing 17/100: Gemini AI can now turn photos into videos
# Processing 18/100: YouTube ‘clarifies’ its plan to demonetize spammy AI slop
# Processing 19/100: Google’s NotebookLM can now make narrated slideshows with AI
# Processing 20/100: Perplexity’s Comet is the AI browser Google wants
# Processing 21/100: Google’s Discover page now summarizes news with AI
# Processing 22/100: Errors found in US judge’s withdrawn decision stink of AI
# Processing 23/100: Trump is bringing back the AI law moratorium
# Processing 24/100: Google’s AI Mode update adds even more tools for students
# Processing 25/100: Why AI researchers are getting paid like NBA All-Stars
# Processing 26/100: Meta is playing the AI game with house money
# Processing 27/100: Google gets its swag back
# Processing 28/100: ChatGPT will ‘better detect’ mental distress after reports of it feeding people’s delusions
# Processing 29/100: Grok stops posting text after flood of antisemitism and Hitler praise
# Processing 30/100: Musk makes grand promises about Grok 4 in the wake of a Nazi chatbot meltdown
# Processing 31/100: Slack says its AI can make sense of your company’s jargon
# Processing 32/100: xAI explains the Grok Nazi meltdown as Tesla puts Elon’s bot in its cars
# Processing 33/100: Adobe’s new AI tool turns silly noises into realistic audio effects
# Processing 34/100: The White House orders tech companies to make AI bigoted again
# Processing 35/100: The $299 Halo smart glasses will remember the names of people you meet
# Processing 36/100: The U.S. May Change Strategy in Its Battle With China for AI Dominance
# Processing 37/100: The Real Demon Inside ChatGPT
# Processing 38/100: Microsoft, OpenAI, and a US Teachers’ Union Are Hatching a Plan to ‘Bring AI into the Classroom’
# Processing 39/100: Trump and the Energy Industry Are Eager to Power AI With Fossil Fuels
# Processing 40/100: How Video Games Became the New Battleground for Actors and AI Protections
# Processing 41/100: Google’s AI Master Plan in One Number
# Processing 42/100: Delta Wants 20% of Flights to Have AI-Powered Dynamic Pricing by the End of 2025
# Processing 43/100: A Hiker Was Missing for Nearly a Year—Until an AI System Recognized His Helmet
# Processing 44/100: ChatGPT’s Study Mode Is Here. It Won’t Fix Education’s AI Problems
# Processing 45/100: Google Will Use AI to Guess People’s Ages Based on Search History
# Processing 46/100: Jack Dorsey Drops His Second New App in a Week
# Processing 47/100: The Rise of AI Is Making Life Even Harder for Real People in Gaza
# Processing 48/100: Apple CEO Tim Cook Calls AI ‘Bigger Than the Internet’ in Rare All-Hands Meeting
# Processing 49/100: YouTube Can’t Put Pandora’s AI Slop Back in the Box
# Processing 50/100: Intel’s Steady Decline Continues With 15% Cut to Staff and Scrapped Factory Plans
# Processing 51/100: People Hated the ‘Squid Game’ Ending, so They’re Using AI to Make New Ones
# Processing 52/100: Samsung Galaxy Watch 8 Hands-On: Gemini Arrives on Wrists and It Could Change Everything
# Processing 53/100: It Started with Games, now It’s the World’s First Ever $4 Trillion Company
# Processing 54/100: A Republican state attorney general is formally investigating why AI chatbots don’t like Donald Trump
# Processing 55/100: Elon Musk’s AI bot adds a ridiculous anime companion with ‘NSFW’ mode
# Processing 56/100: How AI can make us better decision-makers, with Cassie Kozyrkov
# Processing 57/100: ChatGPT can be a disaster for lawyers — Robin AI says it can fix that
# Processing 58/100: Microsoft Edge transforms into an AI browser with new Copilot Mode
# Processing 59/100: Windows 11’s new update will add a bunch of AI features
# Processing 60/100: We need to relearn how to use AI when it’s on our bodies
# Processing 61/100: Delta Air Lines is using AI to set the maximum price you’re willing to pay
# Processing 62/100: Zuckerberg’s ‘personal superintelligence’ plan: fill your free time with more AI
# Processing 63/100: Praise and Addiction Fears: Musk’s AI Girlfriend Sparks Fierce Debate
# Processing 64/100: Replit’s AI Agent Wipes Company’s Codebase During Vibecoding Session
# Processing 65/100: Apple’s Tim Cook Talks Trump Tariffs and AI
# Processing 66/100: Elon Unveils New Grok AI ‘Companion’ That Looks Uncomfortably Familiar
# Processing 67/100: Can ‘MechaHitler’ Pass Trump’s Anti-Woke AI Test?
# Processing 68/100: Read This Before You Trust Any AI-Written Code
# Processing 69/100: DuckDuckGo Is Hoping to Win Over AI-Hating Searchers
# Processing 70/100: Trump Releases His All-American Action Plan for AI
# Processing 71/100: Elon Musk Turns His AI Into a Flirty Anime Girlfriend
# Processing 72/100: China’s BYD Takes the Lead Over Tesla in the Self-Driving Car Wars
# Processing 73/100: Humans Are Starting to Talk More Like ChatGPT, Study Claims
# Processing 74/100: This Small Town Greek Doctor on How He Uses AI: ‘’Without AI, Q Fever Might Not Have Been on Our List”
# Processing 75/100: Google Neutralizes Its Rivals… For Now
# Processing 76/100: AI Won’t Boost Human Productivity Just Yet, a New Paper From the Federal Reserve Says
# Processing 77/100: Tesla Isn’t a Car Company Anymore
# Processing 78/100: Gemini Will Overshadow the Best Upgrades to Google’s New Pixel Buds and Pixel Watch
# Processing 79/100: We are not ready for better deepfakes
# Processing 80/100: Grok will no longer call itself Hitler or base its opinions on Elon Musk’s, promises xAI
# Processing 81/100: 24 hours with Alexa Plus: we cooked, we chatted, and it kinda lied to me
# Processing 82/100: Microsoft’s Copilot Plus features might arrive on desktop PCs later this year
# Processing 83/100: YouTube makes it easy for TV users to skip to the best bits of videos
# Processing 84/100: Samsung’s Galaxy Watch 8 just came out and you can already save $50
# Processing 85/100: GPD’s monster Strix Halo handheld requires a battery ‘backpack’ or a 180W charger
# Processing 86/100: Google dunks on Apple Intelligence in new Pixel 10 ad
# Processing 87/100: OpenAI says ChatGPT users send over 2.5 billion prompts every day
# Processing 88/100: Microsoft’s controversial Recall feature is now blocked by Brave and AdGuard
# Processing 89/100: Microsoft is getting ready for GPT-5 with a new Copilot smart mode
# Processing 90/100: The New Internet Sheriff Takes a Shot at Google
# Processing 91/100: Truth Social Needs Its Own Grok. Trump Has the Trademarks
# Processing 92/100: Wall Street’s AI Bubble Is Worse Than the 1999 Dot-com Bubble, Warns a Top Economist
# Processing 93/100: Report: Disney’s Attempts to Experiment With Generative AI Have Already Hit Major Hurdles
# Processing 94/100: Apple Intelligence tries summarizing news again after botching BBC stories
# Processing 95/100: AI-Powered Shark Robot Vacuum Is 50% Off, Amazon Holds Final Clearance for Prime Day
# Processing 96/100: AI Is Already Disrupting Labor, and Recent Grads Could Be a ‘Lost Generation’
# Processing 97/100: “AI YOUR LIFE”, Anywhere: Hisense Transforms Stadium Excitement into Home Immersion
# Processing 98/100: Meta Is Building Massive Gigawatt Data Centers as It Pours Billions Into AI
# Processing 99/100: Humans Counted 8,600 Earthquakes in Yellowstone. AI Says We’re Not Even Close
# Processing 100/100: Google’s Advanced AI Model Is Now Available to Try—for $250 a Month
# Saved labeled_headlines.csv

# %%
import pandas as pd

# load data
labeled_df = pd.read_csv("labeled_headlines.csv")

# %%
# general overview
# the first 5 rows
print(labeled_df.head())

# columns
print("\nColumns:", labeled_df.columns.tolist())

#number of entries
print("\nTotal headlines:", len(labeled_df))
# Out:
#                                             headline     source sentiment  \
# 0                Join Us for WIRED’s AI Power Summit      Wired  Positive
# 1                        Where Are All the AI Drugs?      Wired   Neutral
# 2         Confessions of a Recovering AI Porn Addict      Wired  Negative
# 3  Android’s Circle to Search feature gets AI and...  The Verge  Positive
# 4  Amazon buys Bee AI wearable that listens to ev...  The Verge   Neutral
#
#         topic         entities         tone   region       intent     time  \
# 0  Technology            WIRED  Promotional  Unknown      Promote   Future
# 1  Technology  None identified  Speculative  Unknown  Report news  Present
# 2  Technology              NaN  Informative  Unknown  Report news  Present
# 3  Technology          Android  Informative   Global  Report news  Present
# 4  Technology   Amazon, Bee AI  Informative   Global  Report news  Present
#
#     emotions clickbait
# 0  Curiosity        No
# 1  Curiosity       Yes
# 2  Curiosity       Yes
# 3  Curiosity        No
# 4  Curiosity        No
#
# Columns: ['headline', 'source', 'sentiment', 'topic', 'entities', 'tone', 'region', 'intent', 'time', 'emotions', 'clickbait']
#
# Total headlines: 100

# %%
# summary of unique values in each category
for col in ["sentiment", "topic", "tone", "region", "intent", "time", "clickbait"]:
    print(f"\n{col.title()} value counts:")
    print(labeled_df[col].value_counts())
# Out:
# Sentiment value counts:
# sentiment
# Neutral                          45
# Negative                         28
# Positive                         26
# Mixed (Positive and Negative)     1
# Name: count, dtype: int64
#
# Topic value counts:
# topic
# Technology                                                          87
# Politics, Technology                                                 5
# Technology, Politics                                                 3
# Unknown (insufficient information to determine a specific topic)     1
# Energy/Technology                                                    1
# Entertainment/Technology                                             1
# Finance/Technology                                                   1
# Finance, Technology                                                  1
# Name: count, dtype: int64
#
# Tone value counts:
# tone
# Informative                 52
# Speculative                 21
# Alarmist                    15
# Promotional                  8
# Informative, Speculative     1
# Informative/Promotional      1
# Informative, Promotional     1
# Neutral                      1
# Name: count, dtype: int64
#
# Region value counts:
# region
# Global       37
# Unknown      35
# US           23
# Europe        2
# US, China     1
# Gaza          1
# China         1
# Name: count, dtype: int64
#
# Intent value counts:
# intent
# Report news             76
# Warn                    14
# Promote                  8
# Persuade                 1
# Report news, Promote     1
# Name: count, dtype: int64
#
# Time value counts:
# time
# Present           76
# Future            17
# Present/Future     6
# Past               1
# Name: count, dtype: int64
#
# Clickbait value counts:
# clickbait
# No     66
# Yes    34
# Name: count, dtype: int64
